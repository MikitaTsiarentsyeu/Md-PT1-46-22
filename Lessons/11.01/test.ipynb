# %%
x = 56
print(x)
# Out:
# 56

# %%
4+6*7
# Out:
# 46

# %% [markdown]
# Implementing a program to calculate a sum of 3 and 4

# %%
3+4
# Out:
# 7

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.linspace(start=-10,stop=10,num=9000000)
y = numpy.sin(x)

plt.plot(x, y)
plt.show()
